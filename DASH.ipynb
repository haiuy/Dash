# %%
import pandas as pd
df1 = pd.read_csv('BTC_H=1_tuning.csv')
df1 = df1.drop(columns='Unnamed: 0')
df1['id_H']=1
df2 = pd.read_csv('BTC_H=2_tuning.csv')
df2 = df2.drop(columns='Unnamed: 0')
df3 = pd.read_csv('BTC_H=3_tuning.csv')
df3 = df3.drop(columns='Unnamed: 0')
df4 = pd.read_csv('BTC_H=4_tuning.csv')
df4 = df4.drop(columns='Unnamed: 0')
dataframe=df1.append(df2).append(df3).append(df4)
dataframe
# Out:
# /var/folders/rs/bwptk0k17bq61j_mw_gqdpg00000gn/T/ipykernel_46062/3958203193.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe=df1.append(df2).append(df3).append(df4)
# /var/folders/rs/bwptk0k17bq61j_mw_gqdpg00000gn/T/ipykernel_46062/3958203193.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe=df1.append(df2).append(df3).append(df4)
#         RMSE     QLIKE       MAE  n_inputs   mlp_units  epochs  learning_rate  \
# 0   0.648719  0.002187  0.534285        10  [512, 512]     450        0.00001
# 1   0.651947  0.002203  0.548189        21  [250, 250]     100        0.00005
# 2   0.582363  0.001730  0.464713        15  [250, 250]     750        0.00005
# 3   0.648014  0.002226  0.534159        84  [712, 712]     650        0.00005
# 4   0.704002  0.002632  0.578847        10  [712, 712]     750        0.00010
# ..       ...       ...       ...       ...         ...     ...            ...
# 25  0.560285  0.001626  0.444642        10  [250, 250]     550        0.00005
# 26  0.648281  0.002153  0.514662        21  [250, 250]     100        0.00001
# 27  0.678089  0.002352  0.550407        15  [712, 712]      50        0.00010
# 28  0.763466  0.002919  0.655210        42  [512, 512]     350        0.00010
# 29  0.737194  0.002691  0.573656        10  [712, 712]     550        0.00010
#
#     num_lr_decays scaler_type  dropout  n_pool_kernel_size pooling_mode  \
# 0               1      minmax      0.2                   2    AvgPool1d
# 1               2      minmax      0.2                   2    MaxPool1d
# 2               2      minmax      0.2                   2    MaxPool1d
# 3               2      minmax      0.4                   2    AvgPool1d
# 4               3      minmax      0.0                   2    AvgPool1d
# ..            ...         ...      ...                 ...          ...
# 25              2    standard      0.2                   1    MaxPool1d
# 26              1    standard      0.0                   1    MaxPool1d
# 27              3      robust      0.2                   0    MaxPool1d
# 28              3      minmax      0.2                   2    MaxPool1d
# 29              3      minmax      0.3                   2    AvgPool1d
#
#    interpolation_mode  n_blocks  random_seed  trial  id_H
# 0             nearest         1     21170174      0     1
# 1              linear         2     53068056      1     1
# 2              linear         1    114940090      2     1
# 3             nearest         2     81839022      3     1
# 4             nearest         2     51504931      4     1
# ..                ...       ...          ...    ...   ...
# 25             linear         5     26037775     25     4
# 26             linear         3     41165234     26     4
# 27             linear         3     66194025     27     4
# 28             linear         1    122236069     28     4
# 29            nearest         5     22922777     29     4
#
# [120 rows x 17 columns]

# %%
from dash import Dash, html, dcc, callback, Output, Input
import plotly.express as px




app = Dash(__name__)

app.layout = html.Div([
    html.H1(children='RMSE comparison', style={'textAlign':'center'}),
    dcc.Dropdown(dataframe.id_H.unique(), '1', id='dropdown-selection'),
    dcc.Graph(id='graph-content')
])

@callback(
    Output('graph-content', 'figure'),
    Input('dropdown-selection', 'value')
)
def update_graph(value):
    record = dataframe[dataframe.id_H==value]
    return px.bar(record,x='trial', y='RMSE',hover_data=['n_inputs', 'mlp_units', 'scaler_type', 'dropout', 'n_pool_kernel_size', 'pooling_mode', 'interpolation_mode', 'n_blocks'],color='scaler_type', title='RMSE comparison', orientation='v' )

if __name__ == '__main__':
    app.run(debug=True)
